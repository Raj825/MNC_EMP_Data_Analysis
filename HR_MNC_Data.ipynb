# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('HR_Data_MNC_Data.csv')
df.head()
# Out:
#    Unnamed: 0 Employee_ID        Full_Name  Department              Job_Title  \
# 0           0  EMP0000001    Joshua Nguyen          IT      Software Engineer
# 1           1  EMP0000002   Julie Williams   Marketing         SEO Specialist
# 2           2  EMP0000003  Alyssa Martinez          HR             HR Manager
# 3           3  EMP0000004  Nicholas Valdez          IT      Software Engineer
# 4           4  EMP0000005   Joel Hendricks  Operations  Logistics Coordinator
#
#     Hire_Date                                 Location  Performance_Rating  \
# 0  2011-08-10                       Isaacland, Denmark                   5
# 1  2018-03-02                  Anthonyside, Costa Rica                   2
# 2  2023-03-20         Port Christinaport, Saudi Arabia                   1
# 3  2023-10-12  Port Shelbychester, Antigua and Barbuda                   1
# 4  2024-12-09     Lake Kimberly, Palestinian Territory                   5
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000000 entries, 0 to 1999999
# Data columns (total 12 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Unnamed: 0          int64
#  1   Employee_ID         object
#  2   Full_Name           object
#  3   Department          object
#  4   Job_Title           object
#  5   Hire_Date           object
#  6   Location            object
#  7   Performance_Rating  int64
#  8   Experience_Years    int64
#  9   Status              object
#  10  Work_Mode           object
#  11  Salary_INR          int64
# dtypes: int64(4), object(8)
# memory usage: 183.1+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# Employee_ID           0
# Full_Name             0
# Department            0
# Job_Title             0
# Hire_Date             0
# Location              0
# Performance_Rating    0
# Experience_Years      0
# Status                0
# Work_Mode             0
# Salary_INR            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Employee_ID', 'Full_Name', 'Department', 'Job_Title',
#        'Hire_Date', 'Location', 'Performance_Rating', 'Experience_Years',
#        'Status', 'Work_Mode', 'Salary_INR'],
#       dtype='object')

# %%
df.drop(columns=['Unnamed: 0'])
# Out:
#         Employee_ID         Full_Name  Department  \
# 0        EMP0000001     Joshua Nguyen          IT
# 1        EMP0000002    Julie Williams   Marketing
# 2        EMP0000003   Alyssa Martinez          HR
# 3        EMP0000004   Nicholas Valdez          IT
# 4        EMP0000005    Joel Hendricks  Operations
# ...             ...               ...         ...
# 1999995  EMP1999996      Cody Russell  Operations
# 1999996  EMP1999997      Tracey Smith          IT
# 1999997  EMP1999998         Tracy Lee       Sales
# 1999998  EMP1999999  Michael Roberson          IT
# 1999999  EMP2000000    Angela Lambert          HR
#
#                              Job_Title   Hire_Date  \
# 0                    Software Engineer  2011-08-10
# 1                       SEO Specialist  2018-03-02
# 2                           HR Manager  2023-03-20
# 3                    Software Engineer  2023-10-12
# 4                Logistics Coordinator  2024-12-09
# ...

# %%
status = df['Status'].value_counts()
status
# Out:
# Status
# Active        1401558
# Resigned       398660
# Retired         99912
# Terminated      99870
# Name: count, dtype: int64

# %%
status.plot(kind='pie',colors='mygr',autopct='%1.1f%%',explode=(0.03,0.03,0.03,0.03,))
plt.show()

# %%
work=df['Work_Mode'].value_counts()

# %%
work.plot(kind='pie',colors='cr',autopct='%1.1f%%',shadow=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dept=df['Department'].value_counts()
dept
# Out:
# Department
# IT            601042
# Sales         400031
# Operations    300095
# Marketing     240081
# Finance       199873
# HR            159119
# R&D            99759
# Name: count, dtype: int64

# %%
dept.plot(kind='pie',colors='mgcr',autopct='%1.1f%%',shadow=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
job=df['Job_Title'].value_counts()
job
# Out:
# Job_Title
# Software Engineer                300358
# Sales Executive                  199982
# Operations Executive             150058
# Data Analyst                     120375
# Marketing Executive              120154
# Account Manager                  119929
# Accountant                       100307
# DevOps Engineer                   90197
# Logistics Coordinator             90188
# HR Executive                      79348
# SEO Specialist                    71692
# Business Development Manager      60233
# IT Manager                        60224
# Financial Analyst                 59815
# Research Scientist                50017
# Talent Acquisition Specialist     47994
# Supply Chain Manager              44935
# Content Strategist                36154
# CTO                               29888
# Product Developer                 29872
# Finance Manager                   29799
# HR Manager                        23841
# Sales Director                    19887
# ...

# %%
job.plot(kind='pie',colors='mgcr',autopct='%1.1f%%',shadow=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Job_Title',palette='BrBG',data=df)
plt.xticks(rotation='vertical')
plt.show()

# %%
dep=df.groupby('Department')['Salary_INR'].mean().astype(int)

# %%
dep.plot(x=dept.index,y=dept.values,kind='bar',color='c')
plt.grid()
plt.title('Average Salary in Department')
plt.ylabel('Salary')
plt.show()

# %%
job=df.groupby('Job_Title')['Salary_INR'].mean().astype(int).reset_index().sort_values(by='Salary_INR',ascending=False).head(10)
job
# Out:
#                         Job_Title  Salary_INR
# 14                     IT Manager     2098155
# 9                 Finance Manager     1743241
# 13                     HR Manager     1252401
# 3    Business Development Manager     1252016
# 26              Software Engineer     1199260
# 10              Financial Analyst     1051522
# 2                   Brand Manager      803127
# 15             Innovation Manager      801870
# 28  Talent Acquisition Specialist      801422
# 5                             CTO      801402

# %%
r_emp=df[df['Status']=='Resigned'].groupby('Department')['Status'].count()
r_emp
# Out:
# Department
# Finance        40238
# HR             31736
# IT            119852
# Marketing      47793
# Operations     59397
# R&D            19919
# Sales          79725
# Name: Status, dtype: int64

# %%
t_emp=df[df['Status']=='Terminated'].groupby('Department')['Status'].count()
t_emp
# Out:
# Department
# Finance        9988
# HR             7861
# IT            29881
# Marketing     12044
# Operations    14884
# R&D            4998
# Sales         20214
# Name: Status, dtype: int64

# %%
r_emp.plot(x=r_emp.index,y=r_emp.values,kind='bar',color='c',legend=True,label='Regined')
t_emp.plot(x=t_emp.index,y=t_emp.values,kind='bar',color='b',legend=True,label='Terminated')
plt.grid()
plt.show()

# %%
pr = df.groupby('Department')['Performance_Rating'].mean().astype(int)
pr
# Out:
# Department
# Finance       2
# HR            2
# IT            2
# Marketing     3
# Operations    2
# R&D           3
# Sales         3
# Name: Performance_Rating, dtype: int64
